# %%
import os

# %%
from daccas import DACCAS

# %%
daccas = DACCAS(models_dir="models", charsets_dir="charsets", device="cpu")

# %%
cls = daccas.Classify(f"../../../Downloads/rotated_images/output/iteration_0_image_1_value_{i}.png")

# %%
for i in range (0,7):
    print("Probability for ", i)
    result = daccas.run(f"../../../Downloads/rotated_images/output/iteration_1_image_1_value_{i}.png")
    print(result)
# Out:
# Probability for  0
# {'classification': {'class': 'Image Rotation (Default)', 'confidence': 1.0, 'raw_name': 'img_rotation_normal'}, 'result': {'class': 'Image Rotation (Default)', 'solver': 'image_rotation_default', 'p_upright': 0.3415820292540682, 'objective': 'maximize', 'crop_mode': 'circular'}}
# Probability for  1
# {'classification': {'class': 'Image Rotation (Default)', 'confidence': 1.0, 'raw_name': 'img_rotation_normal'}, 'result': {'class': 'Image Rotation (Default)', 'solver': 'image_rotation_default', 'p_upright': 0.028220434043187696, 'objective': 'maximize', 'crop_mode': 'circular'}}
# Probability for  2
# {'classification': {'class': 'Image Rotation (Default)', 'confidence': 1.0, 'raw_name': 'img_rotation_normal'}, 'result': {'class': 'Image Rotation (Default)', 'solver': 'image_rotation_default', 'p_upright': 0.3963351685167438, 'objective': 'maximize', 'crop_mode': 'circular'}}
# Probability for  3
# ...
